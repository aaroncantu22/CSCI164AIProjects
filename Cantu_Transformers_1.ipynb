# %% [markdown]
# <a href="https://colab.research.google.com/github/aaroncantu22/CSCI164AIProjects/blob/main/Cantu_Transformers_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(40)

# %%
from IPython.display import Image

# %%
# file 1
# https://drive.google.com/file/d/1ONkV1C3rlqGnfvueZ5ULBs_zdcYV-bey/view?usp=drive_link
# !gdown 1ONkV1C3rlqGnfvueZ5ULBs_zdcYV-bey
file_name1 = "Screenshot 2025-01-27 134906.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ONkV1C3rlqGnfvueZ5ULBs_zdcYV-bey
# To: /content/Screenshot 2025-01-27 134906.png
# 100% 623k/623k [00:00<00:00, 97.8MB/s]

# %%
# file 2
# https://drive.google.com/file/d/1ghTlRV8WwCnvCtvKokkc_Uv6brg_EmN9/view?usp=drive_link
# !gdown 1ghTlRV8WwCnvCtvKokkc_Uv6brg_EmN9
file_name2 = "Screenshot 2024-10-22 133928.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ghTlRV8WwCnvCtvKokkc_Uv6brg_EmN9
# To: /content/Screenshot 2024-10-22 133928.png
# 100% 499k/499k [00:00<00:00, 117MB/s]

# %%
# file 3
# https://drive.google.com/file/d/1cVmqSMeeBGWZsoxXIm-X6Uis6PV9D_HP/view?usp=drive_link
# !gdown 1cVmqSMeeBGWZsoxXIm-X6Uis6PV9D_HP
file_name3 = "Screenshot_23-1-2025_17025_docs.google.com.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cVmqSMeeBGWZsoxXIm-X6Uis6PV9D_HP
# To: /content/Screenshot_23-1-2025_17025_docs.google.com.png
# 100% 101k/101k [00:00<00:00, 60.8MB/s]

# %%
### Task: Image captioning
captioner = pipeline(task="image-to-text",
                     model="nlpconnect/vit-gpt2-image-captioning")
# Out:
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
file_name = file_name1

# %%
captioner2 = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
# Out:
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]

# %%
captioner3 = pipeline("image-to-text", model="Salesforce/blip2-opt-2.7b")
# Out:
# config.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/122k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/882 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]

# %%
captioner(file_name)
# Out:
# [{'generated_text': 'a stuffed bear sitting on a couch next to a stuffed animal '}]

# %%
captioner2(file_name)
# Out:
# [{'generated_text': 'a stuffed animal and a stuffed elephant on a couch'}]

# %%
captioner3(file_name)
# Out:
# [{'generated_text': 'a stuffed animal of an octopus and a stuffed animal of an opossum\n'}]

# %% [markdown]
# # Photo 1

# %%
print(captioner3(file_name1))
display(Image(filename=file_name1))
# Out:
# [{'generated_text': 'a stuffed animal of an octopus and a stuffed animal of an opossum\n'}]

# %% [markdown]
# # Photo 3

# %%
display(Image(filename=file_name2))
captioner3(file_name2)
# Out:
# [{'generated_text': 'halloween michael myers mask\n'}]
